# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from IPython.display import display
from IPython.display import Image
sns.set_context("notebook")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Extracting Data and Filtering
# :The `[]` operator supports array of booleans as an input. In this case, the array must be exactly as long as the number of rows.
#
# The result is a **filtered version of the data frame**, where **only rows corresponding to True appear**.
#
# # Q1.
# Select multiple criteria by creating multiple boolean Series and combining them using the `&` operator. For Examole Result is win and %win is more than 50.

# %%
 # reading a CSV file into a data frame
election=pd.read_csv("/content/drive/MyDrive/DataScience_with_KS/elections.csv")
 #Note: if we end a cell with an expression or variable name, the result will print the data frame

election.head()
# Out:
#    Year          Candidate                  Party  Popular vote Result  \
# 0  1824     Andrew Jackson  Democratic-Republican        151271   loss
# 1  1824  John Quincy Adams  Democratic-Republican        113142    win
# 2  1828     Andrew Jackson             Democratic        642806    win
# 3  1828  John Quincy Adams    National Republican        500897   loss
# 4  1832     Andrew Jackson             Democratic        702735    win
#
#            %
# 0  57.210122
# 1  42.789878
# 2  56.203927
# 3  43.796073
# 4  54.574789

# %%
#apply a boolean condition using the appropriate operator on 2 different conditions like Result should be WIN and % should be GREATER THAN 50
election[(election["Result"]=="win") & (election["Popular vote"]>50)]
# Out:
#      Year               Candidate                  Party  Popular vote Result  \
# 1    1824       John Quincy Adams  Democratic-Republican        113142    win
# 2    1828          Andrew Jackson             Democratic        642806    win
# 4    1832          Andrew Jackson             Democratic        702735    win
# 8    1836        Martin Van Buren             Democratic        763291    win
# 11   1840  William Henry Harrison                   Whig       1275583    win
# 13   1844              James Polk             Democratic       1339570    win
# 16   1848          Zachary Taylor                   Whig       1360235    win
# 17   1852         Franklin Pierce             Democratic       1605943    win
# 20   1856          James Buchanan             Democratic       1835140    win
# 23   1860         Abraham Lincoln             Republican       1855993    win
# 27   1864         Abraham Lincoln         National Union       2211317    win
# ...

# %% [markdown]
# We will nowe work with a dataset containing the names of all babies born in California, USA. Visit the [Social Security Adminisitration Website](https://www.ssa.gov/oact/babynames/limits.html) for more details about the dataset if you want.

# %% [markdown]
# **Let's start by loading the Baby Names dataset.**

# %%
import urllib.request
import os.path
import zipfile
import pandas as pd

data_url = "https://www.ssa.gov/oact/babynames/state/namesbystate.zip"
local_filename = "C:\\Users\MAHTAB\\Root Directory\\Pandas\\babynamesbystate.zip"
if not os.path.exists(local_filename): # if the data exists don't download again
    with urllib.request.urlopen(data_url) as resp, open(local_filename, 'wb') as f:
        f.write(resp.read())

zf = zipfile.ZipFile(local_filename, 'r')

ca_name = 'CA.TXT'
field_names = ['State', 'Sex', 'Year', 'Name', 'Count']
with zf.open(ca_name) as fh:
    babynames = pd.read_csv(fh, header=None, names=field_names)

babynames.head(15)
# Out:
#    State Sex  Year       Name  Count
# 0     CA   F  1910       Mary    295
# 1     CA   F  1910      Helen    239
# 2     CA   F  1910    Dorothy    220
# 3     CA   F  1910   Margaret    163
# 4     CA   F  1910    Frances    134
# 5     CA   F  1910       Ruth    128
# 6     CA   F  1910     Evelyn    126
# 7     CA   F  1910      Alice    118
# 8     CA   F  1910   Virginia    101
# 9     CA   F  1910  Elizabeth     93
# 10    CA   F  1910   Florence     93
# 11    CA   F  1910      Marie     90
# 12    CA   F  1910    Mildred     90
# 13    CA   F  1910       Rose     74
# 14    CA   F  1910      Hazel     68

# %%
#dsplay size
babynames.shape
# Out:
# (413894, 5)

# %% [markdown]
# # Q2.
# Calculate the some statics of babynames DataFrame using Utility Functions, like .describe(), .size, .shape and report your analysis in comments

# %%
#code here
print(babynames.describe())
# Using describe function we analysed that  413894 children born from 1910 to 2023 and in 1910 minimum number of born baby with same
#  name were 5 and max baby with same name untill 2023 were 8263.
# Out:
#                 Year          Count
# count  413894.000000  413894.000000
# mean     1986.314353      79.140348
# std        27.190404     292.028292
# min      1910.000000       5.000000
# 25%      1969.000000       7.000000
# 50%      1992.000000      13.000000
# 75%      2008.000000      38.000000
# max      2023.000000    8263.000000

# %%
print(babynames.info())
# .info is giving us the stats regardin our data and showing if there is any null value in any of column and type of each column
#  and total entries and total memory usage and total columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413894 entries, 0 to 413893
# Data columns (total 5 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   State   413894 non-null  object
#  1   Sex     413894 non-null  object
#  2   Year    413894 non-null  int64
#  3   Name    413894 non-null  object
#  4   Count   413894 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 15.8+ MB
# None

# %%
#code here
babynames.shape
# it is giving information regarding data shape that  there are 413894 entries(rows) and 5 features(column) in our data
# Out:
# (413894, 5)

# %%
babynames.size
# it shows overall size of dataframe by multiplying the all rows with columns and shows that there are 2069470 values
# Out:
# 2069470

# %% [markdown]
# **Add Your comments Here**

# %% [markdown]
# # Q.3:
#
# Using the babynames DataFrame that contains baby names data for the state of California, how can you use the 'isin' method to find out which records have names that are in a given list of names, such as "Emma," "Liam," and "Olivia," and what would be the output of this operation when applied to the first 15 rows of the DataFrame (babynames.head(15))?

# %%
# List of names to check

# Use the isin method to filter records with names in the name_list
print(babynames[babynames["Name"].isin(["Emma","Liam","Olivia"])])
# Display the filtered DataFrame with appropriate head value i.e., 15
babynames[babynames["Name"].isin(["Emma","Liam","Olivia"])].head(15)
# Out:
#        State Sex  Year    Name  Count
# 53        CA   F  1910    Emma     29
# 293       CA   F  1911    Emma     29
# 525       CA   F  1912    Emma     56
# 701       CA   F  1912  Olivia      8
# 840       CA   F  1913    Emma     56
# ...      ...  ..   ...     ...    ...
# 402535    CA   M  2020    Liam   2431
# 405071    CA   M  2020    Emma      5
# 405332    CA   M  2021    Liam   2479
# 408217    CA   M  2022    Liam   2614
# 411113    CA   M  2023    Liam   2594
#
# [286 rows x 5 columns]
#      State Sex  Year    Name  Count
# 53      CA   F  1910    Emma     29
# 293     CA   F  1911    Emma     29
# 525     CA   F  1912    Emma     56
# 701     CA   F  1912  Olivia      8
# 840     CA   F  1913    Emma     56
# 1168    CA   F  1914    Emma     65
# 1437    CA   F  1914  Olivia      6
# 1542    CA   F  1915    Emma     86
# 1869    CA   F  1915  Olivia      6
# 2009    CA   F  1916    Emma     78
# 2195    CA   F  1916  Olivia     12
# ...

# %%
names=["Emma","Liam","Olivia"]
babynames[babynames["Name"].isin(names)]
babynames[babynames["Name"].isin(["Emma","Liam","Olivia"])]
babynames.head()
# Out:
#   State Sex  Year      Name  Count
# 0    CA   F  1910      Mary    295
# 1    CA   F  1910     Helen    239
# 2    CA   F  1910   Dorothy    220
# 3    CA   F  1910  Margaret    163
# 4    CA   F  1910   Frances    134

# %% [markdown]
# # Q.4:
# How can you use the 'str.startswith' method in pandas to filter records in a babyname DataFrame? Provide an example code using the babynames DataFrame and explain how this method can be employed to extract data for baby names that begin with 'A' or 'B' set of letters.

# %%
# Filter rows where the 'Name' column starts with 'A' OR 'B'

# Display the filtered DataFrame
babynames[(babynames["Name"].str.startswith("A")) | (babynames["Name"].str.startswith("B"))]
#print("Baby names starting with 'A' and B:")
babynames[(babynames["Name"].str.startswith("A")) | (babynames["Name"].str.startswith("B"))] # same as confirmed
# Out:
#        State Sex  Year      Name  Count
# 7         CA   F  1910     Alice    118
# 23        CA   F  1910   Bernice     59
# 31        CA   F  1910      Anna     51
# 32        CA   F  1910       Ann     47
# 36        CA   F  1910     Betty     40
# ...      ...  ..   ...       ...    ...
# 413597    CA   M  2023  Bradford      5
# 413598    CA   M  2023    Brahim      5
# 413599    CA   M  2023   Braiden      5
# 413600    CA   M  2023      Bret      5
# 413601    CA   M  2023  Brighton      5
#
# [62932 rows x 5 columns]

# %%
babynames[(babynames["Name"].str.startswith("A") | (babynames["Name"].str.startswith("B")))]
babynames_length=babynames["Name"].str.len()
babynames["babynames_length"]=babynames_length
babynames["babynames_length"]=babynames["babynames_length"]-1
babynames=babynames.rename(columns={"babynames_length":"length"})

# %%
babynames=babynames.drop("length",axis="columns")

# %%
babynames[babynames["Year"]==2000].sample(4)
babynames["length"]=babynames["Name"].str.len()

# %%
babynames[babynames["length"]==2]
# Out:
#        State Sex  Year Name  Count  length
# 4454      CA   F  1920   Jo      5       2
# 4908      CA   F  1921   Jo      9       2
# 6157      CA   F  1923   Jo      8       2
# 6671      CA   F  1924   Jo     16       2
# 7350      CA   F  1925   Jo     17       2
# ...      ...  ..   ...  ...    ...     ...
# 412635    CA   M  2023   Cy     11       2
# 412714    CA   M  2023   Aj     10       2
# 413237    CA   M  2023   Oz      7       2
# 413714    CA   M  2023   Jj      5       2
# 413809    CA   M  2023   Ra      5       2
#
# [980 rows x 6 columns]

# %% [markdown]
# # Q.5
#
# Find the most popular baby name in California in 2012
#
# __Exercise__: Try to find the most popular baby name by finding the maximum value for 'Count' and then apply filtering to find the name.

# %%
# Step 5: Find the maximum count and the corresponding name(s)

max_name=babynames[babynames["Year"].isin([2012])]
max_name=max_name.sort_values(by="Count",ascending=False)
max_name.iloc[0,:]
#Hint: You should apply max on the count but try to get the whole data of that maximum row rather than try to get only the max count.
babynames["length"]=babynames["Name"].str.len()
babynames.sort_values(by="length",ascending=False)
# Out:
#        State Sex  Year             Name  Count  length  name_length_modified
# 325562    CA   M  1991  Franciscojavier      6      15                    15
# 316193    CA   M  1987  Franciscojavier      5      15                    15
# 317627    CA   M  1988  Franciscojavier     10      15                    15
# 320534    CA   M  1989  Franciscojavier      6      15                    15
# 348093    CA   M  2000  Franciscojavier      6      15                    15
# ...      ...  ..   ...              ...    ...     ...                   ...
# 412522    CA   M  2023               Om     13       2                     2
# 327937    CA   M  1992               Ky      7       2                     2
# 327887    CA   M  1992               Ed      7       2                     2
# 326799    CA   M  1992               Bo     27       2                     2
# 327207    CA   M  1992               An     13       2                     2
#
# [413894 rows x 7 columns]

# %%
# babynames.sort_values("Name",key=lambda x:x.str.len(),ascending=False)
# babynames["New_column"]=babynames["length"].apply(lambda x:"High" if x>5 else "Low")
# babynames.apply(lambda row:row["Count"]+row["length"] ,axis= 1)
# babynames["Name"].apply(lambda x: x[:3])
def ae_da_data(value):
  return value.count("e")+value.count("d")
# babynames["ae_da"]=babynames["Name"].apply(ae_da_data)
# babynames.sample(10)
babynames["Name"].apply(lambda value:value.count("a")+value.count("d"))
babynames.groupby("Year")["Count"].sum()
babynames[["Year", "Count"]].groupby("Year").agg(sum)
# Out:
# <ipython-input-78-4b08b0bff1e8>:11: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   babynames[["Year", "Count"]].groupby("Year").agg(sum)
#        Count
# Year
# 1910    9163
# 1911    9983
# 1912   17946
# 1913   22094
# 1914   26926
# ...      ...
# 2019  387325
# 2020  363307
# 2021  363206
# 2022  361960
# 2023  342550
#
# [114 rows x 1 columns]

# %% [markdown]
# # Q. 6
# Find baby names that start with J, in th Year from 2001 to 2019
#
# *Note: To answer this question, we need a way to look at the individual characters of the baby names*

# %%
from os import name
# Note: Series has powerful string manipulation methods associated with it
# Step 5: Find names that start with 'J'
# Find baby names that start with J, in th Year from 2001 to 2019
# names_starting_with_J = babynames[(babynames["Name"].str.startswith("J")) & (babynames["Year"] >= 2001) & (babynames["Year"] <= 2019)]
names_starting_with_J=babynames[(babynames["Name"].str.startswith("J")) & (babynames["Year"]>=2001) & babynames["Year"]<=2019]
#Hint: 3 different conditions in a single boolean condition can be used using an operator

# Step 6: Display the filtered DataFrame with first 15 rows
names_starting_with_J.head(15)
# Out:
#    State Sex  Year       Name  Count  length
# 0     CA   F  1910       Mary    295       4
# 1     CA   F  1910      Helen    239       5
# 2     CA   F  1910    Dorothy    220       7
# 3     CA   F  1910   Margaret    163       8
# 4     CA   F  1910    Frances    134       7
# 5     CA   F  1910       Ruth    128       4
# 6     CA   F  1910     Evelyn    126       6
# 7     CA   F  1910      Alice    118       5
# 8     CA   F  1910   Virginia    101       8
# 9     CA   F  1910  Elizabeth     93       9
# 10    CA   F  1910   Florence     93       8
# 11    CA   F  1910      Marie     90       5
# 12    CA   F  1910    Mildred     90       7
# 13    CA   F  1910       Rose     74       4
# 14    CA   F  1910      Hazel     68       5

# %% [markdown]
# # Q.7
# Add a new column called "name_length" to the babynames DataFrame, you can use .str.len() in existing Name column. Moreover. also modify the Length values with new values like existing_value-1 and rename the length column with new label as desceribe in slides.

# %%
# Calculate the length of each name and add it as a new column "_length"
babynames["name_length"] = babynames["Name"].str.len()

# Modify 'name_length' values to be existing_value - 1
# babynames["name_length_modified"] = babynames["name_length"] - 1

# Rename the 'name_length' column to the new label 'name_length_modified'
babynames.rename(columns={"name_length": "name_length_modified"}, inplace=True)

# Display the first few rows of the modified DataFrame
babynames.head()
# Out:
#   State Sex  Year      Name  Count  length  name_length_modified
# 0    CA   F  1910      Mary    295       4                     4
# 1    CA   F  1910     Helen    239       5                     5
# 2    CA   F  1910   Dorothy    220       7                     7
# 3    CA   F  1910  Margaret    163       8                     8
# 4    CA   F  1910   Frances    134       7                     7

# %% [markdown]
# # Q.8
#
# Use .str.split() to sample the names with 'ad' string and show first 10 samples.

# %%
# Step 4: Filter names that contain 'ad' using str.contains and store it in th variable named ad_names
ad_names = babynames[babynames["Name"].str.contains("ad")]
print(ad_names.head())
# Step 5: Use .str.split() to split names containing 'ad' in ad_names (for demonstration purposes)
names_with_ad = ad_names["Name"].str.split("ad", expand=True)
names_with_ad
# Out:
#     State Sex  Year      Name  Count  length  name_length_modified
# 19     CA   F  1910    Gladys     63       6                     6
# 96     CA   F  1910  Madeline     17       8                     8
# 136    CA   F  1910     Sadie     10       5                     5
# 257    CA   F  1911    Gladys     61       6                     6
# 346    CA   F  1911    Nadine     14       6                     6
#           0      1
# 19       Gl     ys
# 96        M  eline
# 136       S     ie
# 257      Gl     ys
# 346       N    ine
# ...     ...    ...
# 413570  Anh
# 413597   Br   ford
# 413641   El     io
# 413724  Kal     in
# 413882    Z     ok
#
# [7132 rows x 2 columns]

# %% [markdown]
# More on str methods when we'll study regular expressions in this course. Note that there are other approaches that we can use to find the same answer as above.

# %% [markdown]
# # Q.9
#  Sort names by their length using lambda function.

# %%
#Hint: focus on 2 columns here i.e., NAME and LENGTH (apply appropriate parameters using lambda)
# Sort names by their length using lambda function.
babynames['name_length'] = babynames['Name'].apply(lambda x: len(x))
babynames = babynames.sort_values(by='name_length', ascending=False)
babynames = babynames.drop(columns=['name_length'])
babynames.head()
# Out:
#        State Sex  Year             Name  Count  length  name_length_modified
# 341130    CA   M  1997  Ryanchristopher      5      15                    15
# 325441    CA   M  1991  Ryanchristopher      7      15                    15
# 331009    CA   M  1993  Johnchristopher      5      15                    15
# 337819    CA   M  1996  Franciscojavier      8      15                    15
# 348093    CA   M  2000  Franciscojavier      6      15                    15

# %%
new_df=babynames[babynames["Sex"]=="F"]
new_df=new_df.sort_values(by="Year",ascending=False)
# new_df1=babynames.groupby(babynames["Name"])
new_df
# Out:
#        State Sex  Year  Name  Count  length  name_length_modified
# 241264    CA   F  2023   Zya     14       3                     3
# 241559    CA   F  2023   Max     11       3                     3
# 242747    CA   F  2023   Ali      5       3                     3
# 243118    CA   F  2023   Sai      5       3                     3
# 241317    CA   F  2023   Kit     13       3                     3
# ...      ...  ..   ...   ...    ...     ...                   ...
# 200       CA   F  1910  Rosa      6       4                     4
# 201       CA   F  1910  Sara      6       4                     4
# 211       CA   F  1910  Erma      5       4                     4
# 213       CA   F  1910  Faye      5       4                     4
# 228       CA   F  1910  Rena      5       4                     4
#
# [243190 rows x 7 columns]

# %% [markdown]
# # Q.10
# 1: The code randomly mixes up the list of baby names. Why might someone want to do this, and how could it affect the analysis of the names?
#
# 2: After mixing, the code figures out how long each baby name is. Why would we care about name lengths, and what can this tell us about the names?
#
# 3: The code arranges the name lengths from longest to shortest. Why might we want to do this, and what could it help us find in the data?
#
# 4: The code finds the order of baby names based on their lengths and shows us the first few names in this new order. When might we need to organize names this way, and what might we discover from the first few names in this order?

# %%
#This is an entirely theoretical question and you are required to explain your logic in your own words. Make sure not to plagarise your content

#Part1, shuffling can be done using sample(frac=1)



#Part2


#Part3

#Part4

# %% [markdown]
# # Bonus Question
#
# 1: How can you use the .sample() method to randomly select a single row from the babynames DataFrame, and what is the purpose of such a selection?
#
# 2: Suppose you want to generate a random sample of 10 baby names from the babynames DataFrame. How would you use the .sample() method to achieve this, and what parameters or arguments would you specify?
#
# 3: You want to perform a bootstrap resampling analysis on the baby names data in the babynames DataFrame. Describe how you can repeatedly sample with replacement using .sample() to create multiple bootstrap samples for statistical analysis

# %%
#Part 1
babynames
#Use .sample() and explain why should/could we use it to display a single row

#Part 2

#Use .sample() and explain why should/could we use it to display a ten rows.

#Part 3

# Assuming you have the 'babynames' DataFrame

# Set the random seed for reproducibility (read reproducibility in documentation and check out what random_seed does)

# Number of bootstrap samples

# Sample size (same as the original dataset)

# Perform bootstrapping

    # Generate a bootstrap sample with replacement

    # Perform your statistical analysis on the bootstrap sample here
    # For example, you can calculate the mean, median, or other statistics

    # Append the statistic of interest to the list

#Hint: The below link is fun to explore and figure out in more detail what all this is:
#https://stackoverflow.com/questions/31502958/drawing-a-bootstrap-sample-from-a-pandas-dataframe
# Out:
#        State Sex  Year             Name  Count  length  name_length_modified
# 341130    CA   M  1997  Ryanchristopher      5      15                    15
# 325441    CA   M  1991  Ryanchristopher      7      15                    15
# 331009    CA   M  1993  Johnchristopher      5      15                    15
# 337819    CA   M  1996  Franciscojavier      8      15                    15
# 348093    CA   M  2000  Franciscojavier      6      15                    15
# ...      ...  ..   ...              ...    ...     ...                   ...
# 328613    CA   M  1992               Tu      5       2                     2
# 328619    CA   M  1992               Vi      5       2                     2
# 328066    CA   M  1992               Cy      6       2                     2
# 328020    CA   M  1992               Aj      6       2                     2
# 328145    CA   M  1992               Jr      6       2                     2
#
# [413894 rows x 7 columns]
